# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pickle
from sklearn.feature_selection import RFE
import json

import matplotlib.pyplot as plt
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Kushal\AppData\Local\Temp\ipykernel_13620\1081343586.py", line 1, in <module>
#     import pandas as pd
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 39, in <module>
#     from pandas.compat import (
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\compat\__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\compat\pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "C:\Users\Kushal\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Kushal\AppData\Local\Temp\ipykernel_13620\1081343586.py", line 1, in <module>
#     import pandas as pd
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\dtypes\dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "C:\Users\Kushal\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Kushal\AppData\Local\Temp\ipykernel_13620\1081343586.py", line 1, in <module>
#     import pandas as pd
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\array.py", line 50, in <module>
#     from pandas.core import (
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Kushal\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Kushal\anaconda3\Lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Kushal\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Kushal\AppData\Local\Temp\ipykernel_13620\1081343586.py", line 1, in <module>
#     import pandas as pd
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\masked.py", line 60, in <module>
#     from pandas.core import (
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\Kushal\AppData\Roaming\Python\Python312\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Kushal\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Kushal\anaconda3\Lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.

# %%
df = pd.read_csv('tvol_lidarLiveP.csv')
df.head()
# Out:
#    Status  origin      zmax     zmean       zsd     zskew     zkurt  \
# 0       1       0  0.482936  0.393575  0.640931  0.417088  0.000799
# 1       1       0  0.619445  0.744484  0.669192  0.315335  0.035721
# 2       1       0  0.590965  0.552324  0.719417  0.387989  0.005110
# 3       1       0  0.585318  0.735132  0.211343  0.251785  0.194261
# 4       1       0  0.297815  0.381137  0.203122  0.251367  0.095055
#
#    pzabovezmean  pzabove2       zq5  ...    zpcum1    zpcum2    zpcum3  \
# 0      0.653559  0.543409  0.000000  ...  0.228816  0.217799  0.216589
# 1      0.972526  0.832260  0.000000  ...  0.066177  0.098509  0.116252
# 2      0.749769  0.738540  0.000000  ...  0.217498  0.280967  0.292151
# 3      0.687752  0.986705  0.679823  ...  0.001473  0.000000  0.000000
# 4      0.959945  0.893755  0.000000  ...  0.050555  0.047751  0.052850
#
#      zpcum4    zpcum5    zpcum6    zpcum7    zpcum8    zpcum9      Target
# 0  0.214684  0.208958  0.211244  0.275474  0.485716  0.702998  395.095030
# 1  0.120479  0.113527  0.112180  0.112576  0.120256  0.182446  846.770732
# 2  0.288404  0.281392  0.280213  0.282977  0.416297  0.870808  500.279343
# 3  0.000000  0.010708  0.162536  0.361051  0.722317  0.873967  526.744001
# 4  0.056430  0.053567  0.110090  0.504414  0.914992  0.984998  327.607715
#
# [5 rows x 38 columns]

# %%
df = df.sample(frac=1, random_state=42)

X = df.drop('Target', axis=1)  # Drops the Target column and uses the rest as features
y = df['Target']               # Sets the Target column as the dependent variable
#Set aside XTest and YTest for final testing -MZ
X,XTest,y,YTest = train_test_split(X,y,test_size=0.1,random_state=42,shuffle=True)

# %%
X.shape,XTest.shape
# Out:
# ((224, 37), (25, 37))

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Define KFold cross-validation
kf = KFold(n_splits=5, random_state=42, shuffle=True)

# Define the models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(random_state=42),
    "XGBoost": xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
}

# Prepare to collect the metrics
metrics = {name: {'MAE': [], 'RMSE': [], 'R2': []} for name in models.keys()}

# %%
import pandas as pd
import matplotlib.pyplot as plt


for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        # Calculate metrics
        mae = mean_absolute_error(y_test, y_pred)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        
        # Store metrics
        metrics[name]['MAE'].append(mae)
        metrics[name]['RMSE'].append(rmse)
        metrics[name]['R2'].append(r2)

# Convert the metrics dictionary to a DataFrame for easy tabular representation
results_df = pd.DataFrame({name: {
    'MAE': np.mean(metrics[name]['MAE']),
    'RMSE': np.mean(metrics[name]['RMSE']),
    'R2': np.mean(metrics[name]['R2'])
} for name in models.keys()}).T  # Transpose to make models as rows

print("Average Metrics for Each Model:")
display(results_df)

# Plotting
fig, ax = plt.subplots(1, 3, figsize=(18, 5))
results_df['MAE'].plot(kind='bar', ax=ax[0], color='skyblue', title='Mean Absolute Error (MAE)')
results_df['RMSE'].plot(kind='bar', ax=ax[1], color='lightgreen', title='Root Mean Squared Error (RMSE)')
results_df['R2'].plot(kind='bar', ax=ax[2], color='salmon', title='R^2 Score')
plt.tight_layout()
plt.show()
# Out:
# Average Metrics for Each Model:
#                          MAE        RMSE        R2
# Linear Regression  82.276665  112.910546  0.563315
# Random Forest      63.243260   86.232375  0.745243
# XGBoost            70.679106   98.846352  0.666114

# %%
# Initialize variables to find the best model based on RMSE
best_model_name = None
best_rmse = float('inf')

# Iterate through the results to find the model with the lowest RMSE
for name, scores in metrics.items():
    avg_rmse = np.mean(scores['RMSE'])
    if avg_rmse < best_rmse:
        best_rmse = avg_rmse
        best_model_name = name

# Fit the best model on the entire dataset
best_model = models[best_model_name].fit(X, y)

# Save the best model
import pickle
pickle.dump(best_model, open(f"{best_model_name}_Baseline.pkl", 'wb'))

print(f"Saved {best_model_name} as the best model based on RMSE.")
# Out:
# Saved Random Forest as the best model based on RMSE.

# %%
# Initialize variables to find the best model based on R^2
best_model_name = None
best_r2 = float('-inf')  # Start with the lowest possible R^2

# Iterate through the results to find the model with the highest R^2
for name, scores in metrics.items():
    avg_r2 = np.mean(scores['R2'])
    if avg_r2 > best_r2:
        best_r2 = avg_r2
        best_model_name = name

# Fit the best model on the entire dataset
best_model = models[best_model_name].fit(X, y)

# Save the best model
import pickle
pickle.dump(best_model, open(f"{best_model_name}_Baseline.pkl", 'wb'))

print(f"Saved {best_model_name} as the best model based on R^2 score with an average R^2 of {best_r2:.3f}.")
# Out:
# Saved Random Forest as the best model based on R^2 score with an average R^2 of 0.745.

# %% [markdown]
# Week n+1 - Feature Selection

# %%
# Feature Selection with Random Forest (RF) and XGBoost (XGB)
#Train Models to Get Feature Importances

# Assuming X is a DataFrame where columns are feature names
# and y is the target variable.

# Train the Random Forest model
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X, y)
rf_importances = rf_model.feature_importances_

# Train the XGBoost model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
xgb_model.fit(X, y)
xgb_importances = xgb_model.feature_importances_

# Create a DataFrame to visualize feature importances from both models
feature_importances = pd.DataFrame({
    'Feature': X.columns,
    'RF Importance': rf_importances,
    'XGB Importance': xgb_importances
})

# Sort the DataFrame to show more important features first
feature_importances = feature_importances.sort_values(by='RF Importance', ascending=False)

# Display the DataFrame
print(feature_importances)
# Out:
#          Feature  RF Importance  XGB Importance
# 21          zq65       0.201586        0.481851
# 22          zq70       0.188004        0.226904
# 24          zq80       0.136285        0.062993
# 20          zq60       0.093315        0.002698
# 23          zq75       0.075175        0.004152
# 18          zq50       0.035027        0.002091
# 19          zq55       0.033706        0.090128
# 3          zmean       0.024108        0.010308
# 17          zq45       0.023678        0.005682
# 25          zq85       0.021479        0.009841
# 26          zq90       0.016159        0.017401
# 36        zpcum9       0.014522        0.003164
# 9            zq5       0.011303        0.017308
# 27          zq95       0.010148        0.005328
# 29        zpcum2       0.009665        0.001405
# 4            zsd       0.007989        0.001892
# 16          zq40       0.007972        0.018580
# 33        zpcum6       0.007196        0.003012
# 2           zmax       0.006412        0.000944
# 35        zpcum8       0.006236        0.001555
# 7   pzabovezmean       0.005984        0.000323
# 1         origin       0.005906        0.002972
# 34        zpcum7       0.005251        0.001830
# 15          zq35       0.005156        0.003163
# 28        zpcum1       0.004894        0.004756
# 32        zpcum5       0.004846        0.000963
# 10          zq10       0.004801        0.001671
# 30        zpcum3       0.004647        0.006697
# 31        zpcum4       0.004131        0.000156
# 13          zq25       0.004032        0.002219
# 8       pzabove2       0.003777        0.003584
# 12          zq20       0.003777        0.000449
# 14          zq30       0.003731        0.000941
# 6          zkurt       0.003533        0.000916
# 11          zq15       0.003279        0.000542
# 5          zskew       0.002292        0.001582
# 0         Status       0.000000        0.000000

# %%
rf_importances = rf_model.feature_importances_
xgb_importances = xgb_model.feature_importances_

# Select features greater than the median importance
features_rf = X.columns[rf_importances > np.median(rf_importances)].tolist()
features_xgb = X.columns[xgb_importances > np.median(xgb_importances)].tolist()

# Save the selected features to JSON files
with open('Features_RF.json', 'w') as f:
    json.dump(features_rf, f)
with open('Features_XGB.json', 'w') as f:
    json.dump(features_xgb, f)

# Create a DataFrame to visualize feature importances
feature_importances = pd.DataFrame({
    'Feature': X.columns,
    'RF Importance': rf_importances,
    'XGB Importance': xgb_importances
})

# Visualizing feature importances
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.barh(feature_importances['Feature'], feature_importances['RF Importance'], color='skyblue')
plt.title('Random Forest Feature Importances')
plt.xlabel('Importance')

plt.subplot(1, 2, 2)
plt.barh(feature_importances['Feature'], feature_importances['XGB Importance'], color='lightgreen')
plt.title('XGBoost Feature Importances')
plt.xlabel('Importance')

plt.tight_layout()
plt.show()

# %%
#RF-RFE (Recursive Feature Elimination with RF)
#Apply RFE


selector = RFE(rf_model, n_features_to_select=10, step=1)  # adjust 'n_features_to_select' as needed
selector.fit(X, y)

# Get the list of features selected by RFE
rfe_features = X.columns[selector.support_].tolist()

# Save the RFE features to JSON
with open('Features_RFE_RF.json', 'w') as f:
    json.dump(rfe_features, f)

# Extracting the importances of the selected features
rfe_importances = rf_model.feature_importances_[selector.support_]

# Create a DataFrame for visualization
rfe_feature_importances = pd.DataFrame({
    'Feature': rfe_features,
    'Importance': rfe_importances
}).sort_values(by='Importance', ascending=True)

# Visualize the feature importances
plt.figure(figsize=(8, 6))
plt.barh(rfe_feature_importances['Feature'], rfe_feature_importances['Importance'], color='dodgerblue')
plt.title('Feature Importances of Selected Features by RF-RFE')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()

# %%
#Combined RF and XGB Feature Importances
#Combine and Select Features


xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
xgb_model.fit(X, y)
xgb_importances = xgb_model.feature_importances_

# Combine the importances
combined_importances = (rf_importances + xgb_importances) / 2

# Select features whose combined importance is greater than the median
selected_features = X.columns[combined_importances > np.median(combined_importances)].tolist()

# Save the selected features to JSON
with open('Features_RF_XGB.json', 'w') as f:
    json.dump(selected_features, f)

# Create a DataFrame for visualization
combined_feature_importances = pd.DataFrame({
    'Feature': X.columns,
    'Combined Importance': combined_importances
}).sort_values(by='Combined Importance', ascending=True)

# Visualize the combined feature importances
plt.figure(figsize=(10, 8))
plt.barh(combined_feature_importances['Feature'], combined_feature_importances['Combined Importance'], color='purple')
plt.title('Combined RF and XGB Feature Importances')
plt.xlabel('Average Importance')
plt.ylabel('Features')
plt.show()

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import json

# Assuming X, y are already defined in your notebook/data
rf_model = RandomForestRegressor(random_state=42, n_estimators=5, max_depth=3)
rf_model.fit(X, y)
rf_importances = rf_model.feature_importances_

xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42, n_estimators=5, max_depth=3)
xgb_model.fit(X, y)
xgb_importances = xgb_model.feature_importances_

combined_importances = (rf_importances + xgb_importances) / 2
selected_features = X.columns[combined_importances > np.median(combined_importances)].tolist()

with open('Features_RF_XGB.json', 'w') as f:
    json.dump(selected_features, f)

# Calculate R2 scores individually for each feature
r2_scores = []
for feature in X.columns:
    X_single_feature = X[[feature]]
    rf_model.fit(X_single_feature, y)
    xgb_model.fit(X_single_feature, y)
    pred_rf = rf_model.predict(X_single_feature)
    pred_xgb = xgb_model.predict(X_single_feature)
    avg_r2 = np.mean([r2_score(y, pred_rf), r2_score(y, pred_xgb)])
    r2_scores.append(avg_r2)

# DataFrame for visualization
feature_importances_df = pd.DataFrame({
    'Feature': X.columns,
    'Combined Importance': combined_importances,
    'Average R2 Score': r2_scores
}).sort_values(by='Combined Importance', ascending=False)

# Display as table
print(feature_importances_df)

# Visualization
plt.figure(figsize=(10, 8))
plt.barh(feature_importances_df['Feature'], feature_importances_df['Combined Importance'], color='purple')
plt.title('Combined RF and XGB Feature Importances')
plt.xlabel('Average Importance')
plt.ylabel('Features')
plt.show()
# Out:
#          Feature  Combined Importance  Average R2 Score
# 21          zq65             0.213221          0.770229
# 24          zq80             0.168586          0.773680
# 22          zq70             0.168514          0.778344
# 20          zq60             0.148915          0.738734
# 23          zq75             0.079516          0.773714
# 19          zq55             0.048933          0.711513
# 18          zq50             0.037422          0.681154
# 3          zmean             0.029962          0.683818
# 17          zq45             0.014875          0.657884
# 27          zq95             0.014366          0.638593
# 15          zq35             0.013414          0.525703
# 29        zpcum2             0.008786          0.239462
# 26          zq90             0.006546          0.700822
# 5          zskew             0.006360          0.251793
# 9            zq5             0.006201          0.162269
# 25          zq85             0.005421          0.726561
# 10          zq10             0.004662          0.146692
# 14          zq30             0.004599          0.424179
# 2           zmax             0.003851          0.482610
# 28        zpcum1             0.003518          0.195882
# 35        zpcum8             0.003429          0.354467
# 31        zpcum4             0.002878          0.274712
# 7   pzabovezmean             0.002582          0.218780
# 12          zq20             0.001302          0.311937
# 30        zpcum3             0.001209          0.213451
# 16          zq40             0.000528          0.605597
# 6          zkurt             0.000406          0.119780
# 0         Status             0.000000         -0.001226
# 1         origin             0.000000         -0.000498
# 4            zsd             0.000000          0.352722
# 13          zq25             0.000000          0.383948
# 8       pzabove2             0.000000          0.219383
# 11          zq15             0.000000          0.226602
# 32        zpcum5             0.000000          0.313545
# 33        zpcum6             0.000000          0.326202
# 34        zpcum7             0.000000          0.334715
# 36        zpcum9             0.000000          0.399524

# %% [markdown]
# zq65 importance came as most important

# %% [markdown]
# Cross Validation k fold

# %%
import pandas as pd
import numpy as np
import json
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.model_selection import KFold, cross_val_score

# Load your dataset
"""
df = pd.read_csv('tvol_lidarLiveP.csv')
X = df.drop('Target', axis=1)
y = df['Target']
"""

# Set up KFold
kf = KFold(n_splits=5, random_state=42, shuffle=True)

# %%
# Paths to the feature sets
feature_set_files = {
    'RF': 'Features_RF.json',
    'RFE_RF': 'Features_RFE_RF.json',
    'RF_XGB': 'Features_RF_XGB.json',
    'XGB': 'Features_XGB.json'
}

# Load feature sets
feature_sets = {}
for key, filepath in feature_set_files.items():
    with open(filepath, 'r') as file:
        features = json.load(file)
        feature_sets[key] = features

# %%
models = {
    'Random Forest': RandomForestRegressor(random_state=42),
    'XGBoost': xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
}

# %%
# Results dictionary to store the cross-validation results
results = {}

# Evaluate each feature set with each model
for feature_name, features in feature_sets.items():
    results[feature_name] = {}
    X_selected = X[features]
    for model_name, model in models.items():
        # Perform cross-validation
        scores = cross_val_score(model, X_selected, y, cv=kf, scoring='r2')  # Change scoring to 'neg_mean_squared_error' for RMSE
        results[feature_name][model_name] = np.mean(scores)

# Print the results
for feature_set, model_scores in results.items():
    print(f"Results for feature set {feature_set}:")
    for model_name, score in model_scores.items():
        print(f"  {model_name}: Average R^2 Score = {score}")
# Out:
# Results for feature set RF:
#   Random Forest: Average R^2 Score = 0.7374799487458727
#   XGBoost: Average R^2 Score = 0.6592619642151722
# Results for feature set RFE_RF:
#   Random Forest: Average R^2 Score = 0.7195159695154061
#   XGBoost: Average R^2 Score = 0.6072711624357335
# Results for feature set RF_XGB:
#   Random Forest: Average R^2 Score = 0.7461728933958686
#   XGBoost: Average R^2 Score = 0.6100348481131638
# Results for feature set XGB:
#   Random Forest: Average R^2 Score = 0.7451446488199854
#   XGBoost: Average R^2 Score = 0.6771302828454705

# %%
import json
import pickle

# Save the best feature sets for each model
best_features_rf = feature_sets['RF_XGB']
best_features_xgb = feature_sets['RFE_RF']

with open('Best_Features_RF.json', 'w') as f:
    json.dump(best_features_rf, f)

with open('Best_Features_XGB.json', 'w') as f:
    json.dump(best_features_xgb, f)

# Train and save the best models
best_model_rf = RandomForestRegressor(random_state=42)
best_model_xgb = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

best_model_rf.fit(X[best_features_rf], y)
best_model_xgb.fit(X[best_features_xgb], y)

with open('RF_RF_XGB.pkl', 'wb') as f:
    pickle.dump(best_model_rf, f)

with open('RFE_RF_XGB.pkl', 'wb') as f:
    pickle.dump(best_model_xgb, f)

# %% [markdown]
# Week n+ 2 other features

# %%
# Top features from RF and XGB
rf_features = ["zmean", "zsd", "zq5", "zq40", "zq45", "zq50", "zq55", "zq60", "zq65", "zq70", "zq75", "zq80", "zq85", "zq90", "zq95", "zpcum2", "zpcum8", "zpcum9"]
xgb_features = ["zmean", "zq5", "zq50", "zq55", "zq60", "zq65", "zq70", "zq75", "zq80", "zq85"]

# Combine all unique top features for evaluation
all_top_features = list(set(rf_features + xgb_features))

# %%
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.metrics import r2_score
import numpy as np

# Initialize KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Initialize models
rf_model = RandomForestRegressor(random_state=42)
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# %%
# Print column names from DataFrame
print("Columns in DataFrame:", X.columns.tolist())

# Print your list of features
print("Selected features for analysis:", all_top_features)
# Out:
# Columns in DataFrame: ['Status', 'origin', 'zmax', 'zmean', 'zsd', 'zskew', 'zkurt', 'pzabovezmean', 'pzabove2', 'zq5', 'zq10', 'zq15', 'zq20', 'zq25', 'zq30', 'zq35', 'zq40', 'zq45', 'zq50', 'zq55', 'zq60', 'zq65', 'zq70', 'zq75', 'zq80', 'zq85', 'zq90', 'zq95', 'zpcum1', 'zpcum2', 'zpcum3', 'zpcum4', 'zpcum5', 'zpcum6', 'zpcum7', 'zpcum8', 'zpcum9']
# Selected features for analysis: ['zq70', 'zq45', 'zq5', 'zsd', 'zq60', 'zq75', 'zmean', 'zq55', 'zq85', 'zq80', 'zpcum8', 'zpcum2', 'zq65', 'zq50', 'zpcum9', 'zq95', 'zq40', 'zq90']

# %%
feature_scores = {
    'Random Forest': {},
    'XGBoost': {}
}

# Evaluate each feature with both models
for feature in all_top_features:
    if feature in X.columns:  # Check if the feature is in the DataFrame columns
        # Select the current feature for model training
        X_feature = X[[feature]]

        # Initialize lists to store cross-validation scores
        rf_scores = []
        xgb_scores = []

        # Perform cross-validation
        for train_index, test_index in kf.split(X_feature):
            X_train, X_test = X_feature.iloc[train_index], X_feature.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]

            # Random Forest
            rf_model.fit(X_train, y_train)
            y_pred_rf = rf_model.predict(X_test)
            rf_scores.append(r2_score(y_test, y_pred_rf))

            # XGBoost
            xgb_model.fit(X_train, y_train)
            y_pred_xgb = xgb_model.predict(X_test)
            xgb_scores.append(r2_score(y_test, y_pred_xgb))

        # Store average scores
        feature_scores['Random Forest'][feature] = np.mean(rf_scores)
        feature_scores['XGBoost'][feature] = np.mean(xgb_scores)
    else:
        print(f"Feature not found: {feature}")

# %%
# Print the R^2 scores for each feature and model
for model in feature_scores:
    print(f"Model: {model}")
    for feature, score in feature_scores[model].items():
        print(f"  Feature: {feature}, R^2 Score: {score:.4f}")
# Out:
# Model: Random Forest
#   Feature: zq70, R^2 Score: 0.6349
#   Feature: zq45, R^2 Score: 0.4746
#   Feature: zq5, R^2 Score: -0.3950
#   Feature: zsd, R^2 Score: -0.1015
#   Feature: zq60, R^2 Score: 0.6037
#   Feature: zq75, R^2 Score: 0.6254
#   Feature: zmean, R^2 Score: 0.4638
#   Feature: zq55, R^2 Score: 0.5748
#   Feature: zq85, R^2 Score: 0.6377
#   Feature: zq80, R^2 Score: 0.6420
#   Feature: zpcum8, R^2 Score: -0.1841
#   Feature: zpcum2, R^2 Score: -0.3872
#   Feature: zq65, R^2 Score: 0.6170
#   Feature: zq50, R^2 Score: 0.4104
#   Feature: zpcum9, R^2 Score: 0.0111
#   Feature: zq95, R^2 Score: 0.2454
#   Feature: zq40, R^2 Score: 0.3127
#   Feature: zq90, R^2 Score: 0.5211
# Model: XGBoost
#   Feature: zq70, R^2 Score: 0.5157
#   Feature: zq45, R^2 Score: 0.3023
#   Feature: zq5, R^2 Score: -1.0718
#   Feature: zsd, R^2 Score: -0.3609
#   Feature: zq60, R^2 Score: 0.4957
#   Feature: zq75, R^2 Score: 0.5505
#   Feature: zmean, R^2 Score: 0.2895
#   Feature: zq55, R^2 Score: 0.4281
#   Feature: zq85, R^2 Score: 0.3956
#   Feature: zq80, R^2 Score: 0.6067
#   Feature: zpcum8, R^2 Score: -0.5026
#   Feature: zpcum2, R^2 Score: -0.6352
#   Feature: zq65, R^2 Score: 0.5171
#   Feature: zq50, R^2 Score: 0.2986
#   Feature: zpcum9, R^2 Score: -0.3631
#   Feature: zq95, R^2 Score: 0.1520
#   Feature: zq40, R^2 Score: 0.1659
#   Feature: zq90, R^2 Score: 0.3945

# %%
# Convert the feature_scores dictionary to a DataFrame
scores_df = pd.DataFrame(feature_scores)
#print(scores_df)


# Display the DataFrame as a table
display(scores_df)


# Plotting the results
ax = scores_df.plot(kind='bar', figsize=(14, 8), title='Feature Performance Comparison')
ax.set_xlabel('Feature')
ax.set_ylabel('R^2 Score')
plt.show()


# Plotting the results
ax = scores_df.plot(kind='bar', figsize=(14, 8), title='Feature Performance Comparison')
ax.set_xlabel('Feature')
ax.set_ylabel('R^2 Score')
plt.show()

plt.savefig('feature_performance_comparison.png')
# Out:
#         Random Forest   XGBoost
# zq70         0.634857  0.515693
# zq45         0.474552  0.302327
# zq5         -0.394958 -1.071756
# zsd         -0.101453 -0.360852
# zq60         0.603743  0.495670
# zq75         0.625385  0.550471
# zmean        0.463815  0.289498
# zq55         0.574794  0.428098
# zq85         0.637718  0.395631
# zq80         0.641998  0.606737
# zpcum8      -0.184062 -0.502634
# zpcum2      -0.387179 -0.635202
# zq65         0.617035  0.517056
# zq50         0.410366  0.298616
# zpcum9       0.011129 -0.363123
# zq95         0.245431  0.152013
# zq40         0.312651  0.165873
# zq90         0.521071  0.394476

# %%
import pandas as pd
from sklearn.model_selection import KFold
"""
# Load the data
df = pd.read_csv('tvol_lidarLiveP.csv')
df = df.sample(frac=1, random_state=42)  # Shuffle the dataset

X = df.drop('Target', axis=1)  # Drops the Target column and uses the rest as features
y = df['Target'] 
"""

# List your top 8 features
top_features = ["zmean", "zq5", "zq50", "zq55", "zq60", "zq65", "zq70", "zq75"]

# %%
from itertools import combinations

# Generate combinations of features from 3 to 5
feature_combinations = []
for r in range(3, 6):
    feature_combinations.extend(combinations(top_features, r))

# %%
from sklearn.ensemble import RandomForestRegressor  
from sklearn.metrics import r2_score
import numpy as np

# Initialize KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Dictionary to store scores
combination_scores = {}

# Model initialization
model = RandomForestRegressor(random_state=42)

# Evaluate each combination
for combination in feature_combinations:
    X_subset = X[list(combination)]
    scores = []
    for train_index, test_index in kf.split(X_subset):
        X_train, X_test = X_subset.iloc[train_index], X_subset.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        scores.append(r2_score(y_test, y_pred))

    combination_scores[combination] = np.mean(scores)

# %%
# Identify the best combination
best_combination = max(combination_scores, key=combination_scores.get)
best_score = combination_scores[best_combination]

# Train the final model on the entire dataset with the best combination
final_model = RandomForestRegressor(random_state=42)
final_model.fit(X[list(best_combination)], y)

# Save the final model
import pickle
with open('Best_Model_Combination.pkl', 'wb') as f:
    pickle.dump(final_model, f)

# %%
import matplotlib.pyplot as plt

# Data for plotting
combinations = [' + '.join(c) for c in combination_scores.keys()]
scores = list(combination_scores.values())

plt.figure(figsize=(10, 110))
plt.barh(combinations, scores, color='lightblue')
plt.xlabel('R^2 Score')
plt.title('Performance of Feature Combinations')
plt.show()

# %%
# `combination_scores` holds the average score for each feature combination
best_combination = max(combination_scores, key=combination_scores.get)
best_score = combination_scores[best_combination]

# %%
# Retrain the model on the entire dataset with the best feature set
final_model = RandomForestRegressor(random_state=42) 
final_model.fit(X[list(best_combination)], y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Save the model
import pickle
with open('RF_RF_XGB.pkl', 'wb') as file:  
    pickle.dump(final_model, file)

# %%
# Save the model
import pickle
with open('RFE_RF_XGB.pkl', 'wb') as file:  
    pickle.dump(final_model, file)

# %%
# dictionary to keep track of the best models and their scores
best_models = {
    'RF_RF_XGB': {'model': None, 'score': -float('inf')},
    'RFE_RF_XGB': {'model': None, 'score': -float('inf')}
}

# Update this dictionary based on actual evaluations
for combination, score in combination_scores.items():
    model_identifier = 'RF_RF_XGB'  # Update logic to assign the correct identifier
    if score > best_models[model_identifier]['score']:
        # Update the best model for this identifier
        best_model = RandomForestRegressor(random_state=42)
        best_model.fit(X[list(combination)], y)
        best_models[model_identifier] = {'model': best_model, 'score': score}

# Now save all best models
for identifier, info in best_models.items():
    with open(f'{identifier}.pkl', 'wb') as file:
        pickle.dump(info['model'], file)

# %%
import logging

# Setting up logging to display the model evaluation process
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, KFold

# Assuming top_features and X, y are already defined
kf = KFold(n_splits=5, shuffle=True, random_state=42)
model = RandomForestRegressor(random_state=42)  # Example model
combination_scores = {}

for combination in feature_combinations:
    X_subset = X[list(combination)]
    scores = cross_val_score(model, X_subset, y, cv=kf, scoring='r2')
    average_score = np.mean(scores)
    combination_scores[combination] = average_score
    logging.info(f"Evaluated combination: {combination} | Average R^2 score: {average_score}")

# Identifying the best combination
best_combination = max(combination_scores, key=combination_scores.get)
best_score = combination_scores[best_combination]
logging.info(f"Best combination: {best_combination} with R^2 score: {best_score}")
# Out:
# 2025-04-24 20:49:43,031 - INFO - Evaluated combination: ('zmean', 'zq5', 'zq50') | Average R^2 score: 0.6799149647958377
# 2025-04-24 20:49:44,934 - INFO - Evaluated combination: ('zmean', 'zq5', 'zq55') | Average R^2 score: 0.718856011278206
# 2025-04-24 20:49:46,803 - INFO - Evaluated combination: ('zmean', 'zq5', 'zq60') | Average R^2 score: 0.7139670906976173
# 2025-04-24 20:49:48,665 - INFO - Evaluated combination: ('zmean', 'zq5', 'zq65') | Average R^2 score: 0.7127965228948604
# 2025-04-24 20:49:50,579 - INFO - Evaluated combination: ('zmean', 'zq5', 'zq70') | Average R^2 score: 0.7319066339741107
# 2025-04-24 20:49:52,466 - INFO - Evaluated combination: ('zmean', 'zq5', 'zq75') | Average R^2 score: 0.7247585181577366
# 2025-04-24 20:49:54,381 - INFO - Evaluated combination: ('zmean', 'zq50', 'zq55') | Average R^2 score: 0.6484731704658602
# 2025-04-24 20:49:56,333 - INFO - Evaluated combination: ('zmean', 'zq50', 'zq60') | Average R^2 score: 0.6484028718899747
# 2025-04-24 20:49:58,254 - INFO - Evaluated combination: ('zmean', 'zq50', 'zq65') | Average R^2 score: 0.6644990647327299
# 2025-04-24 20:50:00,270 - INFO - Evaluated combination: ('zmean', 'zq50', 'zq70') | Average R^2 score: 0.7013362075717324
# 2025-04-24 20:50:01,996 - INFO - Evaluated combination: ('zmean', 'zq50', 'zq75') | Average R^2 score: 0.6979525784672987
# 2025-04-24 20:50:03,852 - INFO - Evaluated combination: ('zmean', 'zq55', 'zq60') | Average R^2 score: 0.6757751773191657
# 2025-04-24 20:50:05,824 - INFO - Evaluated combination: ('zmean', 'zq55', 'zq65') | Average R^2 score: 0.6749211429707904
# 2025-04-24 20:50:07,684 - INFO - Evaluated combination: ('zmean', 'zq55', 'zq70') | Average R^2 score: 0.7177810461108242
# 2025-04-24 20:50:09,603 - INFO - Evaluated combination: ('zmean', 'zq55', 'zq75') | Average R^2 score: 0.7113428325199118
# 2025-04-24 20:50:11,742 - INFO - Evaluated combination: ('zmean', 'zq60', 'zq65') | Average R^2 score: 0.660738481723237
# 2025-04-24 20:50:13,763 - INFO - Evaluated combination: ('zmean', 'zq60', 'zq70') | Average R^2 score: 0.6972638693710949
# 2025-04-24 20:50:15,695 - INFO - Evaluated combination: ('zmean', 'zq60', 'zq75') | Average R^2 score: 0.6920414352431922
# 2025-04-24 20:50:17,654 - INFO - Evaluated combination: ('zmean', 'zq65', 'zq70') | Average R^2 score: 0.6916938446894134
# 2025-04-24 20:50:19,651 - INFO - Evaluated combination: ('zmean', 'zq65', 'zq75') | Average R^2 score: 0.6946078185028371
# 2025-04-24 20:50:21,627 - INFO - Evaluated combination: ('zmean', 'zq70', 'zq75') | Average R^2 score: 0.6943645058270491
# 2025-04-24 20:50:23,485 - INFO - Evaluated combination: ('zq5', 'zq50', 'zq55') | Average R^2 score: 0.621717722228359
# 2025-04-24 20:50:25,332 - INFO - Evaluated combination: ('zq5', 'zq50', 'zq60') | Average R^2 score: 0.6481608709144429
# 2025-04-24 20:50:27,235 - INFO - Evaluated combination: ('zq5', 'zq50', 'z
 'zq65', 'zq70', 'zq75') | Average R^2 score: 0.7093890501052911
# 2025-04-24 20:55:50,030 - INFO - Evaluated combination: ('zq55', 'zq60', 'zq65', 'zq70', 'zq75') | Average R^2 score: 0.7173695592745687
# 2025-04-24 20:55:50,030 - INFO - Best combination: ('zmean', 'zq5', 'zq55', 'zq70', 'zq75') with R^2 score: 0.7486552835893272

# %%
import json

# Dictionary to store combinations with R^2 score >= 0.7
high_scoring_combinations = {comb: score for comb, score in combination_scores.items() if score >= 0.73}

# Printing out the results
print("Feature combinations with R^2 score >= 0.7:")
for combination, score in high_scoring_combinations.items():
    print(f"Combination {combination}: R^2 Score = {score}")

# Save the high-scoring combinations to a JSON file
with open('best_feature_combo.json', 'w') as f:
    # Convert tuple keys to string for JSON serialization
    json.dump({str(comb): score for comb, score in high_scoring_combinations.items()}, f, indent=4)
# Out:
# Feature combinations with R^2 score >= 0.7:
# Combination ('zmean', 'zq5', 'zq70'): R^2 Score = 0.7319066339741107
# Combination ('zq5', 'zq55', 'zq75'): R^2 Score = 0.7477456918759005
# Combination ('zq5', 'zq65', 'zq75'): R^2 Score = 0.7309423023402613
# Combination ('zmean', 'zq5', 'zq55', 'zq70'): R^2 Score = 0.7473923315238002
# Combination ('zmean', 'zq5', 'zq55', 'zq75'): R^2 Score = 0.7445867086832294
# Combination ('zmean', 'zq5', 'zq60', 'zq70'): R^2 Score = 0.7313122658063685
# Combination ('zmean', 'zq5', 'zq65', 'zq70'): R^2 Score = 0.7378253277137583
# Combination ('zmean', 'zq5', 'zq65', 'zq75'): R^2 Score = 0.7367260549763623
# Combination ('zmean', 'zq5', 'zq70', 'zq75'): R^2 Score = 0.7326932553316645
# Combination ('zq5', 'zq50', 'zq65', 'zq75'): R^2 Score = 0.7327995964202676
# Combination ('zq5', 'zq55', 'zq60', 'zq75'): R^2 Score = 0.7398022924008432
# Combination ('zq5', 'zq55', 'zq65', 'zq75'): R^2 Score = 0.7467639008935498
# Combination ('zq5', 'zq55', 'zq70', 'zq75'): R^2 Score = 0.7410548112437183
# Combination ('zq5', 'zq60', 'zq65', 'zq75'): R^2 Score = 0.7335183874749915
# Combination ('zmean', 'zq5', 'zq50', 'zq55', 'zq70'): R^2 Score = 0.7345622282066143
# Combination ('zmean', 'zq5', 'zq50', 'zq55', 'zq75'): R^2 Score = 0.7326871882003512
# Combination ('zmean', 'zq5', 'zq50', 'zq65', 'zq75'): R^2 Score = 0.7302664836256445
# Combination ('zmean', 'zq5', 'zq50', 'zq70', 'zq75'): R^2 Score = 0.7315068008955518
# Combination ('zmean', 'zq5', 'zq55', 'zq60', 'zq70'): R^2 Score = 0.7377630966223059
# Combination ('zmean', 'zq5', 'zq55', 'zq60', 'zq75'): R^2 Score = 0.744234247816489
# Combination ('zmean', 'zq5', 'zq55', 'zq65', 'zq70'): R^2 Score = 0.7432392393958673
# Combination ('zmean', 'zq5', 'zq55', 'zq65', 'zq75'): R^2 Score = 0.7448303867429122
# Combination ('zmean', 'zq5', 'zq55', 'zq70', 'zq75'): R^2 Score = 0.7486552835893272
# Combination ('zmean', 'zq5', 'zq60', 'zq65', 'zq70'): R^2 Score = 0.7320171464367031
# Combination ('zmean', 'zq5', 'zq60', 'zq65', 'zq75'): R^2 Score = 0.7355271626124126
# Combination ('zmean', 'zq5', 'zq60', 'zq70', 'zq75'): R^2 Score = 0.7368570003157398
# Combination ('zmean', 'zq5', 'zq65', 'zq70', 'zq75'): R^2 Score = 0.7368888331242157
# Combination ('zq5', 'zq50', 'zq55', 'zq65', 'zq75'): R^2 Score = 0.731941096441173
# Combination ('zq5', 'zq55', 'zq60', 'zq65', 'zq75'): R^2 Score = 0.7424838724835535
# Combination ('zq5', 'zq55', 'zq60', 'zq70', 'zq75'): R^2 Score = 0.7426558932911334
# Combination ('zq5', 'zq55', 'zq65', 'zq70', 'zq75'): R^2 Score = 0.742565361259179

# %%
import matplotlib.pyplot as plt

# Prepare data for plotting
labels = [' + '.join(comb) for comb in high_scoring_combinations.keys()]
scores = list(high_scoring_combinations.values())

# Create bar plot
plt.figure(figsize=(10, 8))
plt.barh(labels, scores, color='green')
plt.xlabel('R^2 Score')
plt.title('High Performing Feature Combinations')
plt.show()

# %%
import matplotlib.pyplot as plt

# Prepare data for plotting
labels = [' + '.join(comb) for comb in high_scoring_combinations.keys()]
scores = list(high_scoring_combinations.values())

# Create a horizontal bar plot
plt.figure(figsize=(10, 8))
bars = plt.barh(labels, scores, color='green')

# Add a text label next to each bar displaying the exact R² score
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2,
             f'{bar.get_width():.2f}',  # Formatting the number with two decimal places
             va='center')

# Set labels and title
plt.xlabel('R² Score')
plt.title('High Performing Feature Combinations')
plt.show()






# Create bar plot
plt.figure(figsize=(10, 8))
plt.barh(labels, scores, color='green')
plt.xlabel('R^2 Score')
plt.title('High Performing Feature Combinations')
plt.show()

# %%
import json
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import pickle

# Load the high-scoring combinations from JSON
with open('best_feature_combo.json', 'r') as file:
    high_scoring_combinations = json.load(file)

# %%
# DataFrame to keep track of the models
import os
model_details = pd.DataFrame(columns=['Model Name', 'Features', 'R2 Score'])

outfile = "ensemble4.csv"

model_counter = 1

# Parse and train models for each combination
for combo_str, score in high_scoring_combinations.items():
    # Convert string representation of tuple back to actual tuple
    combination = eval(combo_str)
    
    model = RandomForestRegressor(random_state=42)
    model.fit(X[list(combination)], y)  # Train only on selected features
    
    # Evaluate the model on the validation set
    r2_score = model.score(XTest[list(combination)], YTest)
    Ypred=model.predict(XTest[list(combination)])
    if os.path.exists(outfile):
        resultdf = pd.read_csv(outfile)
        resultdf["Model"+str(model_counter)]=Ypred
        resultdf.to_csv(outfile,index=None)
        print("The file exists.")
    else:
        resultdf=pd.DataFrame()
        resultdf["Actual"]=YTest
        resultdf["Model"+str(model_counter)]=Ypred
        resultdf.to_csv(outfile,index=None)
        print("The file does not exist.")

    
    # Save the model
    model_filename = f'M{model_counter}.pkl'
    """
    with open(model_filename, 'wb') as file:
        pickle.dump(model, file)
    """
    

    # Append details to the DataFrame
    model_details.loc[model_counter] = [model_filename, ', '.join(combination), r2_score]

    model_counter += 1

# Save the DataFrame to an Excel file
#model_details.to_excel('model_details.xlsx', index=False)
# Out:
# The file does not exist.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.
# The file exists.

# %%
print(model_details)
# Out:
#    Model Name                      Features  R2 Score
# 1      M1.pkl              zmean, zq5, zq70  0.862781
# 2      M2.pkl               zq5, zq55, zq75  0.855805
# 3      M3.pkl               zq5, zq65, zq75  0.860500
# 4      M4.pkl        zmean, zq5, zq55, zq70  0.881880
# 5      M5.pkl        zmean, zq5, zq55, zq75  0.885995
# 6      M6.pkl        zmean, zq5, zq60, zq70  0.883331
# 7      M7.pkl        zmean, zq5, zq65, zq70  0.897709
# 8      M8.pkl        zmean, zq5, zq65, zq75  0.890275
# 9      M9.pkl        zmean, zq5, zq70, zq75  0.854741
# 10    M10.pkl         zq5, zq50, zq65, zq75  0.875071
# 11    M11.pkl         zq5, zq55, zq60, zq75  0.863271
# 12    M12.pkl         zq5, zq55, zq65, zq75  0.861788
# 13    M13.pkl         zq5, zq55, zq70, zq75  0.854900
# 14    M14.pkl         zq5, zq60, zq65, zq75  0.869007
# 15    M15.pkl  zmean, zq5, zq50, zq55, zq70  0.887930
# 16    M16.pkl  zmean, zq5, zq50, zq55, zq75  0.885714
# 17    M17.pkl  zmean, zq5, zq50, zq65, zq75  0.895302
# 18    M18.pkl  zmean, zq5, zq50, zq70, zq75  0.886494
# 19    M19.pkl  zmean, zq5, zq55, zq60, zq70  0.887024
# 20    M20.pkl  zmean, zq5, zq55, zq60, zq75  0.895869
# 21    M21.pkl  zmean, zq5, zq55, zq65, zq70  0.893854
# 22    M22.pkl  zmean, zq5, zq55, zq65, zq75  0.893615
# 23    M23.pkl  zmean, zq5, zq55, zq70, zq75  0.882691
# 24    M24.pkl  zmean, zq5, zq60, zq65, zq70  0.881542
# 25    M25.pkl  zmean, zq5, zq60, zq65, zq75  0.888896
# 26    M26.pkl  zmean, zq5, zq60, zq70, zq75  0.882085
# 27    M27.pkl  zmean, zq5, zq65, zq70, zq75  0.886004
# 28    M28.pkl   zq5, zq50, zq55, zq65, zq75  0.869164
# 29    M29.pkl   zq5, zq55, zq60, zq65, zq75  0.865029
# 30    M30.pkl   zq5, zq55, zq60, zq70, zq75  0.856727
# 31    M31.pkl   zq5, zq55, zq65, zq70, zq75  0.861149

# %%
# Now read ensemble.csv and do simple average in 2nd stage - MZ, March 20, 2025
from sklearn.metrics import r2_score
kf=KFold(n_splits=5, random_state=42, shuffle=True)
stage2df = pd.read_csv("ensemble4.csv")
Y2=stage2df["Actual"]
X2=stage2df.iloc[:,1:]
#lr=RandomForestRegressor(random_state=42)
Ypred = [np.mean(X2.iloc[i,:]) for i in range(X2.shape[0])]
# Calculate metrics
mae = mean_absolute_error(Y2, Ypred)
rmse = np.sqrt(mean_squared_error(Y2, Ypred))
r2 = r2_score(Y2, Ypred)
print(r2)
# Out:
# 0.8876538136839243

# %%
stage2df
# Out:
#         Actual      Model1      Model2      Model3      Model4      Model5  \
# 0   274.382136  281.629381  383.779404  340.861545  296.244202  354.229537
# 1   425.574716  589.011252  557.157966  531.833636  591.237752  578.429989
# 2    92.176928   96.495693  112.520904  111.586172   95.800517  100.389020
# 3    59.327344   94.377563  115.998127  121.061038   92.489430   95.201423
# 4   646.159263  594.529896  680.949319  657.123382  648.968813  650.974265
# 5   167.072870  151.267957  218.704269  204.032946  136.710492  181.794753
# 6   118.427000  137.131714  147.055794  146.594436  137.642371  141.448206
# 7    45.229324   82.826133  119.217059  118.439328  104.665906  103.528036
# 8   160.885283  149.000993  133.648168  139.393666  153.376094  149.538282
